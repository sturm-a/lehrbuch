# %% [markdown]
# ### Aufgaben
#
#
# Aussicht	|Temp	|Feuchtigkeit |	Wind	|Golf spielen
# ------------|-------|-------------|----------|---------
# Regnerisch|	heiß	|hoch|	nein|	nein
# Regnerisch|	heiß |	hoch|	ja	|nein
# Wolkig |		heiß	|hoch	|	nein|	ja
# Sonnig |	mild |	hoch|	nein|ja
# Sonnig |	kalt |	normal |	nein	|ja
# Sonnig		|kalt|	normal |	ja|	nein
# wolkig |	kalt	|normal		|ja	 |ja
# regnerisch|	mild |	hoch|	nein|	nein
# regnerisch|	kalt |	normal |	nein |	ja
# Sonnig |	mild |	normal |	nein |	ja
# regnerisch|	mild |	normal |	ja	 |ja
# wolkig |	mild |	hoch|		ja|	ja
# wolkig |	heiß |	normal |	nein |	ja
# Sonnig |	mild |	hoch|	ja	|nein
#
#
# Entropie= Entropie(5.9)= Entropie(0.36,0.64)= -(0.36 log2 0.36) – (0.64 log2 0.64) =0.94
# Entropie mit zwei Attributen
# 				Golf spielen
# 				Ja 	nein
#                 Sonnig 	3 2 5
#     Ausblick	wolkig	40	4
#                 Regnerisch	23 5
# 						      14
# E(Golf spielen, Ausblick)= P(sonning)*E(3,2)+P(wolkig)*E(4,0)+ P(regnerisch)*E(2,3)
# =(5/14)*0.971+(4/14)*0.0 + (5/14)*0.971
# =0.693
#
# Information gain
# Schritt 1
# Entropie(golf spielen)= Entropie(5,9)
# 		=Entropie(0.36, 0.64)
# 		=-(0.36 log2 0.36)-(0.64 log2 0.64)
# 		=0.94
# Schritt 2
# Unterteilen des Datensatzes nach verschiedenen Attributen
# 				Golf spielen
# 				Ja	nein
# 		Sonnig		3	2
# Ausblick	wolkig		4	0
# 		Regnerisch	2	3
# Gain =
#
#
#
#
#
#
# 				Golf spielen
# 				Ja	nein
# 		heiß		2	2
# Temp.		mild		4	2
# 		Kalt		3	1
# Gain =
#
# 				Golf spielen
# 				Ja	nein
# 		hoch		3	4
# Feuchtigkeit	normal		6	1
# Gain =
#
# 				Golf spielen
# 				Ja	nein
# 		ja		6	2
# Wind		nein		3	3
# Gain =
#
# Gain(T,X)= Entropie(T) – Entropie(T,X)
# G(golf spielen, Ausblick) = E(golf spielen) – E(golf spielen, Ausblick) = 0.940 – 0.693 = 0.247
# Erstelle die Regeln für den Baum:
#
# R1= IF (Aussicht=Sonne) AND (Wind=nein) THEN spielen=ja
# R1= IF (Aussicht=Sonne) AND (Wind=ja) THEN spielen=nein
# R1= IF (Aussicht=Wolkig) THEN spielen=ja
# R1= IF (Aussicht=Regnerisch) AND (Feuchtigkeit=hoch) THEN spielen=nein
# R1= IF (Aussicht=Regnerisch) AND (Feuchtigkeit=normal) THEN spielen=ja
